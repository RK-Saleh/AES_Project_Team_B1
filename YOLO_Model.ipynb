# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 32.6 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="HOzmwRbpl40Q2jXmfokB")
project = rf.workspace("3-class-airplane-drone-helicopter").project("airplane-drone-helicopter")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 33.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 33.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.18
#     Uninstalling idna-3.18:
#       Successfully uninstalled idna-3.18
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Airplane-Drone-Helicopter-2 in yolov8:: 100%|██████████| 69254/69254 [00:12<00:00, 5452.02it/s]
# ...

# %%
from ultralytics import YOLO

# 1. Load the lightweight Nano model base
model = YOLO('yolov8n.pt')

# 2. Kick off the training loop
# NOTE: Replace 'YOUR-FOLDER-NAME' with the exact name of the folder
# that appeared in your left sidebar after the Roboflow download.
results = model.train(
    data='/content/Airplane-Drone-Helicopter-2/data.yaml',
    epochs=15,
    imgsz=640
)
# Out:
# ...
# Ultralytics 8.4.72 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO
import shutil
from google.colab import files

# ==========================================
# CHANGE THIS TO MATCH YOUR FINAL FOLDER!
# For example: 'train', 'train-2', 'train-3'
FOLDER_NAME = 'train'
# ==========================================

print(f"⚙️ Exporting the model from {FOLDER_NAME} to NCNN format...")
# 1. Load the best weights
best_model = YOLO(f'/content/runs/detect/{FOLDER_NAME}/weights/best.pt')

# 2. Convert to NCNN
best_model.export(format='ncnn')

print("📦 Zipping the NCNN folder...")
# 3. Zip it up
shutil.make_archive('/content/best_ncnn_model', 'zip', f'/content/runs/detect/{FOLDER_NAME}/weights/best_ncnn_model')

print("⬇️ Downloading to your computer...")
# 4. Force browser download
files.download('/content/best_ncnn_model.zip')
# Out:
# ⚙️ Exporting the model from train to NCNN format...
# Ultralytics 8.4.72 🚀 Python-3.12.13 torch-2.11.0+cu128 CPU (Intel Xeon CPU @ 2.00GHz)
# WARNING ⚠️ NCNN export does not support end2end models, disabling end2end branch.
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 73 layers, 3,007,208 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/runs/detect/train/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 12, 8400) (6.0 MB)
# requirements: Ultralytics requirement ['ncnn'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 1 package in 183ms
# Prepared 1 package in 441ms
# Installed 1 package in 2ms
#  + ncnn==1.0.20260526
#
# requirements: AutoUpdate success ✅ 1.1s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# ...
